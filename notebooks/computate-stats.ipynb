# %%
from matplotlib import pyplot as plt
import numpy as np
import json

# %%
data = dict([
    ('ResNet152', './results/nn-from-resnet152-moma-artworks-1000--2018-12-26-09-54-07.npy.json'),
    ('DenseNet', './results/nn-from-densenet-moma-artworks-1000--2018-12-26-09-56-26.npy.json'),
    ('VGG16', './results/nn-from-vgg16-moma-artworks-1000--2018-12-26-10-01-39.npy.json')
])


# get data filter only original artworks
# compute precision recall at (1, 3, 5)

# %%
def get_id(path):
    return path.split('/')[-1].split('.')[0]

def get_stats(path, k=3, max_rel_items=5, epsilon=np.finfo(float).eps):
    with open(path,'r') as f:
        dd = json.load(f)

        num_relevant_items = []
        for idx, item in enumerate(dd):
            id_prefix = '%s--' % get_id(item['artwork']['image'])

            sim_ids = list(filter(lambda s: id_prefix in get_id(s['image']) , item['sims'][:k]))


            num_relevant_items.append(float(len(sim_ids)))
        num_relevant_items = np.array(num_relevant_items)
        print('computing stats from %d items' % num_relevant_items.shape[0])
        precision = num_relevant_items / k
        recall = num_relevant_items / max_rel_items
        f1 = 2*((precision*recall)/(precision+recall+epsilon))
    return (np.mean(precision), np.mean(recall), np.mean(f1)), (np.std(precision), np.std(recall), np.std(f1))
get_stats(data['ResNet152'])
# Out:
# computing stats from 989 items
# ((0.6740815638692281, 0.4044489383215369, 0.505561172901921),
#  (0.293645125065506, 0.1761870750393036, 0.22023384379912944))

# %%
kk = [1, 3, 5]

def get_all_stats():
    stats = {}
    for dk, v in data.items():
        m = np.zeros((3, 3))
        s = np.zeros((3, 3))
        for i, k in enumerate(kk):
            st = get_stats(v, k=k)
            m[i, :] = st[0]
            s[i, :] = st[1]
        stats[dk] = {
            'mean': m,
            'std': s
        }
    return stats

stats = get_all_stats()
# Out:
# computing stats from 989 items
# computing stats from 989 items
# computing stats from 989 items
# computing stats from 989 items
# computing stats from 989 items
# computing stats from 989 items
# computing stats from 989 items
# computing stats from 989 items
# computing stats from 989 items

# %%
titles = [
    'Precision',
    'Recall',
    'F1'
]
plt.figure(figsize=(18, 4))

for idx in range(3):
    plt.subplot(1, 3, idx+1)
    for dk in data.keys():
#         plt.plot(kk, , 'o-', label=dk)
        print(idx)
        print(stats[dk]['std'][:, idx])
        y = stats[dk]['mean'][:, idx]
        std = stats[dk]['std'][:, idx]
        plt.errorbar(kk, y, fmt='o-', label=dk)
        plt.fill_between(kk, y+std, y-std, alpha=0.05)

    if idx == 0:
        plt.legend()
    elif idx == 1:
        plt.plot(kk, np.array(kk)/5, '--', label=dk)
    elif idx == 2:
        max_f1 = map(lambda r: 2*((1.0*r)/(1.0+r)),  np.array(kk)/5)
        plt.plot(kk, list(max_f1), '--', label=dk)


    plt.ylim((0.1, 1.05))
    plt.xticks(kk, kk)
    plt.xlabel('k')
    plt.title(titles[idx])
# Out:
# 0
# [0.26310561 0.29364513 0.20130773]
# 0
# [0.23495925 0.29301233 0.20775235]
# 0
# [0.04492388 0.06474868 0.11364547]
# 1
# [0.05262112 0.17618708 0.20130773]
# 1
# [0.04699185 0.1758074  0.20775235]
# 1
# [0.00898478 0.03884921 0.11364547]
# 2
# [0.08770187 0.22023384 0.20130773]
# 2
# [0.07831975 0.21975925 0.20775235]
# 2
# [0.01497463 0.04856151 0.11364547]

# %%
stats['VGG16']['std'][:, 0]*2
# Out:
# array([0.08984776, 0.12949737, 0.22729095])
