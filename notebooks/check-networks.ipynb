# %%
import torchvision.models as models
import torch.nn as nn
from torchsummary import summary

import torch
import numpy as np

# %%
densenet = models.densenet201(pretrained=True)
# Out:
# /Users/heytitle/projects/venv-python3/lib/python3.6/site-packages/torchvision/models/densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)

# %%
summary(densenet, input_size=(3, 224, 224))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1         [-1, 64, 112, 112]           9,408
#        BatchNorm2d-2         [-1, 64, 112, 112]             128
#               ReLU-3         [-1, 64, 112, 112]               0
#          MaxPool2d-4           [-1, 64, 56, 56]               0
#        BatchNorm2d-5           [-1, 64, 56, 56]             128
#               ReLU-6           [-1, 64, 56, 56]               0
#             Conv2d-7          [-1, 128, 56, 56]           8,192
#        BatchNorm2d-8          [-1, 128, 56, 56]             256
#               ReLU-9          [-1, 128, 56, 56]               0
#            Conv2d-10           [-1, 32, 56, 56]          36,864
#       BatchNorm2d-11           [-1, 96, 56, 56]             192
#              ReLU-12           [-1, 96, 56, 56]               0
#            Conv2d-13          [-1, 128, 56, 56]          12,288
# ...

# %%
# Out:
# /Users/heytitle/projects/venv-python3/lib/python3.6/site-packages/torchvision/models/squeezenet.py:94: UserWarning: nn.init.kaiming_uniform is now deprecated in favor of nn.init.kaiming_uniform_.
#   init.kaiming_uniform(m.weight.data)
# /Users/heytitle/projects/venv-python3/lib/python3.6/site-packages/torchvision/models/squeezenet.py:92: UserWarning: nn.init.normal is now deprecated in favor of nn.init.normal_.
#   init.normal(m.weight.data, mean=0.0, std=0.01)

# %%
# sn = nn.Sequential(*list(densenet.children())[0][:-1])
# summary(sn, input_size=(3, 224, 224))
# densenet.features.remove_module('norm5')
import torch.nn.functional as F
summary(F.relu(densenet.features), input_size=(3,224, 224))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-70-dc1a3077b4ce> in <module>
#       3 # densenet.features.remove_module('norm5')
#       4 import torch.nn.functional as F
# ----> 5 summary(F.relu(densenet.features), input_size=(3,224, 224))
#
# ~/projects/venv-python3/lib/python3.6/site-packages/torch/nn/functional.py in relu(input, inplace)
#     641     if inplace:
#     642         return torch.relu_(input)
# --> 643     return torch.relu(input)
#     644
#     645
#
# TypeError: relu(): argument 'input' (position 1) must be Tensor, not Sequential

# %%
features = densenet.features.forward(torch.rand(1, 3, 224, 224))
out = F.relu(features)
out = F.adaptive_avg_pool2d(out, (1, 1)).view(features.size(0), -1)
out.shape
# Out:
# torch.Size([1, 1920])

# %%
densenet.classifier
# Out:
# Linear(in_features=1920, out_features=1000, bias=True)

# %%
ly1 = list(sn.children())[:4]
ly2 = list(sn.children())[4:5]

# %%
list(sn.children())[4:]
# Out:
# [_DenseBlock(
#    (denselayer1): _DenseLayer(
#      (norm1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#      (relu1): ReLU(inplace)
#      (conv1): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#      (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#      (relu2): ReLU(inplace)
#      (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#    )
#    (denselayer2): _DenseLayer(
#      (norm1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#      (relu1): ReLU(inplace)
#      (conv1): Conv2d(96, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#      (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#      (relu2): ReLU(inplace)
#      (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#    )
#    (denselayer3): _DenseLayer(
# ...
